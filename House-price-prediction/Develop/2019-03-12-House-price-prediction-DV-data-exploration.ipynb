# %% [markdown]
# # House Price Prediction

# %% [markdown]
# ### Data Lit || Homework Assignment || Regression

# %% [markdown]
# by Denis Volchugin

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import missingno as msngo

import warnings
warnings.filterwarnings("ignore")

from scipy import stats
from pivottablejs import pivot_ui

from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression, RidgeCV, LassoCV, ElasticNetCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, make_scorer

sns.set()
pd.set_option('display.float_format', lambda x: '{:.3f}'.format(x))

# %matplotlib inline

# %%
test = pd.read_csv ('../Data/test.csv')
train = pd.read_csv ('../Data/train.csv')

# %%
pd.set_option ('display.max_columns', 500)
pd.set_option ('display.max_rows', 500)

# %% [markdown]
# ## OK, what do we have here?

# %%
train.head(10)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL       65.000     8450   Pave   NaN      Reg
# 1   2          20       RL       80.000     9600   Pave   NaN      Reg
# 2   3          60       RL       68.000    11250   Pave   NaN      IR1
# 3   4          70       RL       60.000     9550   Pave   NaN      IR1
# 4   5          60       RL       84.000    14260   Pave   NaN      IR1
# 5   6          50       RL       85.000    14115   Pave   NaN      IR1
# 6   7          20       RL       75.000    10084   Pave   NaN      Reg
# 7   8          60       RL          nan    10382   Pave   NaN      IR1
# 8   9          50       RM       51.000     6120   Pave   NaN      Reg
# 9  10         190       RL       50.000     7420   Pave   NaN      Reg
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
# 5         Lvl    AllPub    Inside       Gtl      Mitchel       Norm
# 6         Lvl    AllPub    Inside       Gtl      Somerst       Norm
# 7         Lvl    AllPub    Corner       Gtl       NWAmes       PosN
# 8         Lvl    AllPub    Inside       Gtl      OldTown     Artery
# 9         Lvl    AllPub    Corner       Gtl      BrkSide     Artery
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm     1Fam     2Story            7            5       2003
# 1       Norm     1Fam     1Story            6            8       1976
# 2       Norm     1Fam     2Story            7            5       2001
# 3       Norm     1Fam     2Story            7            5       1915
# 4       Norm     1Fam     2Story            8            5       2000
# 5       Norm     1Fam     1.5Fin            5            5       1993
# 6       Norm     1Fam     1Story            8            5       2004
# 7       Norm     1Fam     2Story            7            6       1973
# 8       Norm     1Fam     1.5Fin            7            5       1931
# 9     Artery   2fmCon     1.5Unf            5            6       1939
#
#    YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 0          2003     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1          1976     Gable  CompShg     MetalSd     MetalSd       None
# 2          2002     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 3          1970     Gable  CompShg     Wd Sdng     Wd Shng       None
# 4          2000     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 5          1995     Gable  CompShg     VinylSd     VinylSd       None
# 6          2005     Gable  CompShg     VinylSd     VinylSd      Stone
# 7          1973     Gable  CompShg     HdBoard     HdBoard      Stone
# 8          1950     Gable  CompShg     BrkFace     Wd Shng       None
# 9          1950     Gable  CompShg     MetalSd     MetalSd       None
#
#    MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 0     196.000        Gd        TA      PConc       Gd       TA           No
# 1       0.000        TA        TA     CBlock       Gd       TA           Gd
# 2     162.000        Gd        TA      PConc       Gd       TA           Mn
# 3       0.000        TA        TA     BrkTil       TA       Gd           No
# 4     350.000        Gd        TA      PConc       Gd       TA           Av
# 5       0.000        TA        TA       Wood       Gd       TA           No
# 6     186.000        Gd        TA      PConc       Ex       TA           Av
# 7     240.000        TA        TA     CBlock       Gd       TA           Mn
# 8       0.000        TA        TA     BrkTil       TA       TA           No
# 9       0.000        TA        TA     BrkTil       TA       TA           No
#
#   BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          GLQ         706          Unf           0        150          856
# 1          ALQ         978          Unf           0        284         1262
# 2          GLQ         486          Unf           0        434          920
# 3          ALQ         216          Unf           0        540          756
# 4          GLQ         655          Unf           0        490         1145
# 5          GLQ         732          Unf           0         64          796
# 6          GLQ        1369          Unf           0        317         1686
# 7          ALQ         859          BLQ          32        216         1107
# 8          Unf           0          Unf           0        952          952
# 9          GLQ         851          Unf           0        140          991
#
#   Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 0    GasA        Ex          Y      SBrkr       856       854             0
# 1    GasA        Ex          Y      SBrkr      1262         0             0
# 2    GasA        Ex          Y      SBrkr       920       866             0
# 3    GasA        Gd          Y      SBrkr       961       756             0
# 4    GasA        Ex          Y      SBrkr      1145      1053             0
# 5    GasA        Ex          Y      SBrkr       796       566             0
# 6    GasA        Ex          Y      SBrkr      1694         0             0
# 7    GasA        Ex          Y      SBrkr      1107       983             0
# 8    GasA        Gd          Y      FuseF      1022       752             0
# 9    GasA        Ex          Y      SBrkr      1077         0             0
#
#    GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 0       1710             1             0         2         1             3
# 1       1262             0             1         2         0             3
# 2       1786             1             0         2         1             3
# 3       1717             1             0         1         0             3
# 4       2198             1             0         2         1             4
# 5       1362             1             0         1         1             1
# 6       1694             1             0         2         0             3
# 7       2090             1             0         2         1             3
# 8       1774             0             0         2         0             2
# 9       1077             1             0         1         0             2
#
#    KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu  \
# 0             1          Gd             8        Typ           0         NaN
# 1             1          TA             6        Typ           1          TA
# 2             1          Gd             6        Typ           1          TA
# 3             1          Gd             7        Typ           1          Gd
# 4             1          Gd             9        Typ           1          TA
# 5             1          TA             5        Typ           0         NaN
# 6             1          Gd             7        Typ           1          Gd
# 7             1          TA             7        Typ           2          TA
# 8             2          TA             8       Min1           2          TA
# 9             2          TA             5        Typ           2          TA
#
#   GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# 0     Attchd     2003.000          RFn           2         548         TA
# 1     Attchd     1976.000          RFn           2         460         TA
# 2     Attchd     2001.000          RFn           2         608         TA
# 3     Detchd     1998.000          Unf           3         642         TA
# 4     Attchd     2000.000          RFn           3         836         TA
# 5     Attchd     1993.000          Unf           2         480         TA
# 6     Attchd     2004.000          RFn           2         636         TA
# 7     Attchd     1973.000          RFn           2         484         TA
# 8     Detchd     1931.000          Unf           2         468         Fa
# 9     Attchd     1939.000          RFn           1         205         Gd
#
#   GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 0         TA          Y           0           61              0          0
# 1         TA          Y         298            0              0          0
# 2         TA          Y           0           42              0          0
# 3         TA          Y           0           35            272          0
# 4         TA          Y         192           84              0          0
# 5         TA          Y          40           30              0        320
# 6         TA          Y         255           57              0          0
# 7         TA          Y         235          204            228          0
# 8         TA          Y          90            0            205          0
# 9         TA          Y           0            4              0          0
#
#    ScreenPorch  PoolArea PoolQC  Fence MiscFeature  MiscVal  MoSold  YrSold  \
# 0            0         0    NaN    NaN         NaN        0       2    2008
# 1            0         0    NaN    NaN         NaN        0       5    2007
# 2            0         0    NaN    NaN         NaN        0       9    2008
# 3            0         0    NaN    NaN         NaN        0       2    2006
# 4            0         0    NaN    NaN         NaN        0      12    2008
# 5            0         0    NaN  MnPrv        Shed      700      10    2009
# 6            0         0    NaN    NaN         NaN        0       8    2007
# 7            0         0    NaN    NaN        Shed      350      11    2009
# 8            0         0    NaN    NaN         NaN        0       4    2008
# 9            0         0    NaN    NaN         NaN        0       1    2008
#
#   SaleType SaleCondition  SalePrice
# 0       WD        Normal     208500
# 1       WD        Normal     181500
# 2       WD        Normal     223500
# 3       WD       Abnorml     140000
# 4       WD        Normal     250000
# 5       WD        Normal     143000
# 6       WD        Normal     307000
# 7       WD        Normal     200000
# 8       WD       Abnorml     129900
# 9       WD        Normal     118000

# %%
Dscr = train.describe(include='all').T
Dscr
# Out:
#                  count unique      top  freq       mean       std       min  \
# Id            1460.000    NaN      NaN   NaN    730.500   421.610     1.000
# MSSubClass    1460.000    NaN      NaN   NaN     56.897    42.301    20.000
# MSZoning          1460      5       RL  1151        NaN       NaN       NaN
# LotFrontage   1201.000    NaN      NaN   NaN     70.050    24.285    21.000
# LotArea       1460.000    NaN      NaN   NaN  10516.828  9981.265  1300.000
# Street            1460      2     Pave  1454        NaN       NaN       NaN
# Alley               91      2     Grvl    50        NaN       NaN       NaN
# LotShape          1460      4      Reg   925        NaN       NaN       NaN
# LandContour       1460      4      Lvl  1311        NaN       NaN       NaN
# Utilities         1460      2   AllPub  1459        NaN       NaN       NaN
# LotConfig         1460      5   Inside  1052        NaN       NaN       NaN
# LandSlope         1460      3      Gtl  1382        NaN       NaN       NaN
# Neighborhood      1460     25    NAmes   225        NaN       NaN       NaN
# Condition1        1460      9     Norm  1260        NaN       NaN       NaN
# Condition2        1460      8     Norm  1445        NaN       NaN       NaN
# BldgType          1460      5     1Fam  1220        NaN       NaN       NaN
# HouseStyle        1460      8   1Story   726        NaN       NaN       NaN
# OverallQual   1460.000    NaN      NaN   NaN      6.099     1.383     1.000
# OverallCond   1460.000    NaN      NaN   NaN      5.575     1.113     1.000
# YearBuilt     1460.000    NaN      NaN   NaN   1971.268    30.203  1872.000
# YearRemodAdd  1460.000    NaN      NaN   NaN   1984.866    20.645  1950.000
# RoofStyle         1460      6    Gable  1141        NaN       NaN       NaN
# RoofMatl          1460      8  CompShg  1434        NaN       NaN       NaN
# Exterior1st       1460     15  VinylSd   515        NaN       NaN       NaN
# Exterior2nd       1460     16  VinylSd   504        NaN       NaN       NaN
# MasVnrType        1452      4     None   864        NaN       NaN       NaN
# MasVnrArea    1452.000    NaN      NaN   NaN    103.685   181.066     0.000
# ExterQual         1460      4       TA   906        NaN       NaN       NaN
# ExterCond         1460      5       TA  1282        NaN       NaN       NaN
# Foundation        1460      6    PConc   647        NaN       NaN       NaN
# BsmtQual          1423      4       TA   649        NaN       NaN       NaN
# BsmtCond          1423      4       TA  1311        NaN       NaN       NaN
# BsmtExposure      1422      4       No   953        NaN       NaN       NaN
# BsmtFinType1      1423      6      Unf   430        NaN       NaN       NaN
# BsmtFinSF1    1460.000    NaN      NaN   NaN    443.640   456.098     0.000
# BsmtFinType2      1422      6      Unf  1256        NaN       NaN       NaN
# BsmtFinSF2    1460.000    NaN      NaN   NaN     46.549   161.319     0.000
# BsmtUnfSF     1460.000    NaN      NaN   NaN    567.240   441.867     0.000
# TotalBsmtSF   1460.000    NaN      NaN   NaN   1057.429   438.705     0.000
# Heating           1460      6     GasA  1428        NaN       NaN       NaN
# HeatingQC         1460      5       Ex   741        NaN       NaN       NaN
# CentralAir        1460      2        Y  1365        NaN       NaN       NaN
# Electrical        1459      5    SBrkr  1334        NaN       NaN       NaN
# 1stFlrSF      1460.000    NaN      NaN   NaN   1162.627   386.588   334.000
# 2ndFlrSF      1460.000    NaN      NaN   NaN    346.992   436.528     0.000
# LowQualFinSF  1460.000    NaN      NaN   NaN      5.845    48.623     0.000
# GrLivArea     1460.000    NaN      NaN   NaN   1515.464   525.480   334.000
# BsmtFullBath  1460.000    NaN      NaN   NaN      0.425     0.519     0.000
# BsmtHalfBath  1460.000    NaN      NaN   NaN      0.058     0.239     0.000
# FullBath      1460.000    NaN      NaN   NaN      1.565     0.551     0.000
# HalfBath      1460.000    NaN      NaN   NaN      0.383     0.503     0.000
# BedroomAbvGr  1460.000    NaN      NaN   NaN      2.866     0.816     0.000
# KitchenAbvGr  1460.000    NaN      NaN   NaN      1.047     0.220     0.000
# KitchenQual       1460      4       TA   735        NaN       NaN       NaN
# TotRmsAbvGrd  1460.000    NaN      NaN   NaN      6.518     1.625     2.000
# Functional        1460      7      Typ  1360        NaN       NaN       NaN
# Fireplaces    1460.000    NaN      NaN   NaN      0.613     0.645     0.000
# FireplaceQu        770      5       Gd   380        NaN       NaN       NaN
# GarageType        1379      6   Attchd   870        NaN       NaN       NaN
# GarageYrBlt   1379.000    NaN      NaN   NaN   1978.506    24.690  1900.000
# GarageFinish      1379      3      Unf   605        NaN       NaN       NaN
# GarageCars    1460.000    NaN      NaN   NaN      1.767     0.747     0.000
# GarageArea    1460.000    NaN      NaN   NaN    472.980   213.805     0.000
# GarageQual        1379      5       TA  1311        NaN       NaN       NaN
# GarageCond        1379      5       TA  1326        NaN       NaN       NaN
# PavedDrive        1460      3        Y  1340        NaN       NaN       NaN
# WoodDeckSF    1460.000    NaN      NaN   NaN     94.245   125.339     0.000
# OpenPorchSF   1460.000    NaN      NaN   NaN     46.660    66.256     0.000
# EnclosedPorch 1460.000    NaN      NaN   NaN     21.954    61.119     0.000
# 3SsnPorch     1460.000    NaN      NaN   NaN      3.410    29.317     0.000
# ScreenPorch   1460.000    NaN      NaN   NaN     15.061    55.757     0.000
# PoolArea      1460.000    NaN      NaN   NaN      2.759    40.177     0.000
# PoolQC               7      3       Gd     3        NaN       NaN       NaN
# Fence              281      4    MnPrv   157        NaN       NaN       NaN
# MiscFeature         54      4     Shed    49        NaN       NaN       NaN
# MiscVal       1460.000    NaN      NaN   NaN     43.489   496.123     0.000
# MoSold        1460.000    NaN      NaN   NaN      6.322     2.704     1.000
# YrSold        1460.000    NaN      NaN   NaN   2007.816     1.328  2006.000
# SaleType          1460      9       WD  1267        NaN       NaN       NaN
# SaleCondition     1460      6   Normal  1198        NaN       NaN       NaN
# SalePrice     1460.000    NaN      NaN   NaN 180921.196 79442.503 34900.000
#
#                      25%        50%        75%        max
# Id               365.750    730.500   1095.250   1460.000
# MSSubClass        20.000     50.000     70.000    190.000
# MSZoning             NaN        NaN        NaN        NaN
# LotFrontage       59.000     69.000     80.000    313.000
# LotArea         7553.500   9478.500  11601.500 215245.000
# Street               NaN        NaN        NaN        NaN
# Alley                NaN        NaN        NaN        NaN
# LotShape             NaN        NaN        NaN        NaN
# LandContour          NaN        NaN        NaN        NaN
# Utilities            NaN        NaN        NaN        NaN
# LotConfig            NaN        NaN        NaN        NaN
# LandSlope            NaN        NaN        NaN        NaN
# Neighborhood         NaN        NaN        NaN        NaN
# Condition1           NaN        NaN        NaN        NaN
# Condition2           NaN        NaN        NaN        NaN
# BldgType             NaN        NaN        NaN        NaN
# HouseStyle           NaN        NaN        NaN        NaN
# OverallQual        5.000      6.000      7.000     10.000
# OverallCond        5.000      5.000      6.000      9.000
# YearBuilt       1954.000   1973.000   2000.000   2010.000
# YearRemodAdd    1967.000   1994.000   2004.000   2010.000
# RoofStyle            NaN        NaN        NaN        NaN
# RoofMatl             NaN        NaN        NaN        NaN
# Exterior1st          NaN        NaN        NaN        NaN
# Exterior2nd          NaN        NaN        NaN        NaN
# MasVnrType           NaN        NaN        NaN        NaN
# MasVnrArea         0.000      0.000    166.000   1600.000
# ExterQual            NaN        NaN        NaN        NaN
# ExterCond            NaN        NaN        NaN        NaN
# Foundation           NaN        NaN        NaN        NaN
# BsmtQual             NaN        NaN        NaN        NaN
# BsmtCond             NaN        NaN        NaN        NaN
# BsmtExposure         NaN        NaN        NaN        NaN
# BsmtFinType1         NaN        NaN        NaN        NaN
# BsmtFinSF1         0.000    383.500    712.250   5644.000
# BsmtFinType2         NaN        NaN        NaN        NaN
# BsmtFinSF2         0.000      0.000      0.000   1474.000
# BsmtUnfSF        223.000    477.500    808.000   2336.000
# TotalBsmtSF      795.750    991.500   1298.250   6110.000
# Heating              NaN        NaN        NaN        NaN
# HeatingQC            NaN        NaN        NaN        NaN
# CentralAir           NaN        NaN        NaN        NaN
# Electrical           NaN        NaN        NaN        NaN
# 1stFlrSF         882.000   1087.000   1391.250   4692.000
# 2ndFlrSF           0.000      0.000    728.000   2065.000
# LowQualFinSF       0.000      0.000      0.000    572.000
# GrLivArea       1129.500   1464.000   1776.750   5642.000
# BsmtFullBath       0.000      0.000      1.000      3.000
# BsmtHalfBath       0.000      0.000      0.000      2.000
# FullBath           1.000      2.000      2.000      3.000
# HalfBath           0.000      0.000      1.000      2.000
# BedroomAbvGr       2.000      3.000      3.000      8.000
# KitchenAbvGr       1.000      1.000      1.000      3.000
# KitchenQual          NaN        NaN        NaN        NaN
# TotRmsAbvGrd       5.000      6.000      7.000     14.000
# Functional           NaN        NaN        NaN        NaN
# Fireplaces         0.000      1.000      1.000      3.000
# FireplaceQu          NaN        NaN        NaN        NaN
# GarageType           NaN        NaN        NaN        NaN
# GarageYrBlt     1961.000   1980.000   2002.000   2010.000
# GarageFinish         NaN        NaN        NaN        NaN
# GarageCars         1.000      2.000      2.000      4.000
# GarageArea       334.500    480.000    576.000   1418.000
# GarageQual           NaN        NaN        NaN        NaN
# GarageCond           NaN        NaN        NaN        NaN
# PavedDrive           NaN        NaN        NaN        NaN
# WoodDeckSF         0.000      0.000    168.000    857.000
# OpenPorchSF        0.000     25.000     68.000    547.000
# EnclosedPorch      0.000      0.000      0.000    552.000
# 3SsnPorch          0.000      0.000      0.000    508.000
# ScreenPorch        0.000      0.000      0.000    480.000
# PoolArea           0.000      0.000      0.000    738.000
# PoolQC               NaN        NaN        NaN        NaN
# Fence                NaN        NaN        NaN        NaN
# MiscFeature          NaN        NaN        NaN        NaN
# MiscVal            0.000      0.000      0.000  15500.000
# MoSold             5.000      6.000      8.000     12.000
# YrSold          2007.000   2008.000   2009.000   2010.000
# SaleType             NaN        NaN        NaN        NaN
# SaleCondition        NaN        NaN        NaN        NaN
# SalePrice     129975.000 163000.000 214000.000 755000.000

# %% [markdown]
# It looks like some people sell houses, some people buy houses...
# Can we use this info somehow? To tell the truth, the job is not very inspiring, but it has to be done!
# Like Russians say - "once the carriage is grasped, don't say you can't manage it!"

# %% [markdown]
# ### What kind of cargo can we drop to move faster?

# %%
msngo.matrix(train, labels=True, fontsize=12);

# %%
msngo.matrix(test, labels=True, fontsize=12);

# %% [markdown]
# two files are pretty similar. some data is missing, but we can live with that. I'll just pretend I don't see that empty columns. But, wait a minute? is there any reason to wait for? I don't think so.

# %%
train.drop([
    'LotFrontage', 'Alley', 'FireplaceQu', 'PoolQC', 'Fence',
    'MiscFeature'
],
           axis=1,
           inplace=True)
test.drop([
    'LotFrontage', 'Alley', 'FireplaceQu', 'PoolQC', 'Fence',
    'MiscFeature'
],
          axis=1,
          inplace=True)

# %% [markdown]
# I've noticed that we've got 2 blocks of info concerning Basement and Garage with a lot of missing values.

# %%
train[train['GarageFinish'].isna()][:30]
# Out:
#       Id  MSSubClass MSZoning  LotArea Street LotShape LandContour Utilities  \
# 39    40          90       RL     6040   Pave      Reg         Lvl    AllPub
# 48    49         190       RM     4456   Pave      Reg         Lvl    AllPub
# 78    79          90       RL    10778   Pave      Reg         Lvl    AllPub
# 88    89          50  C (all)     8470   Pave      IR1         Lvl    AllPub
# 89    90          20       RL     8070   Pave      Reg         Lvl    AllPub
# 99   100          20       RL     9320   Pave      IR1         Lvl    AllPub
# 108  109          50       RM     8500   Pave      Reg         Lvl    AllPub
# 125  126         190       RM     6780   Pave      Reg         Lvl    AllPub
# 127  128          45       RM     4388   Pave      IR1         Bnk    AllPub
# 140  141          20       RL    10500   Pave      Reg         Lvl    AllPub
# 148  149          20       RL     7500   Pave      Reg         Lvl    AllPub
# 155  156          50       RL     9600   Pave      Reg         Lvl    AllPub
# 163  164          45       RL     5500   Pave      Reg         Lvl    AllPub
# 165  166         190       RL    10106   Pave      Reg         Lvl    AllPub
# 198  199          75       RM     5520   Pave      Reg         Lvl    AllPub
# 210  211          30       RL     5604   Pave      Reg         Lvl    AllPub
# 241  242          30       RM     3880   Pave      Reg         Lvl    AllPub
# 250  251          30       RL     5350   Pave      IR1         Lvl    AllPub
# 287  288          20       RL     8125   Pave      IR1         Lvl    AllPub
# 291  292         190       RL     5687   Pave      Reg         Bnk    AllPub
# 307  308          50       RM     7920   Pave      IR1         Lvl    AllPub
# 375  376          30       RL    10020   Pave      IR1         Low    AllPub
# 386  387          50       RL     8410   Pave      Reg         Lvl    AllPub
# 393  394          30       RL     7446   Pave      Reg         Lvl    AllPub
# 431  432          50       RM     5586   Pave      IR1         Bnk    AllPub
# 434  435         180       RM     1890   Pave      Reg         Lvl    AllPub
# 441  442          90       RL    12108   Pave      Reg         Lvl    AllPub
# 464  465          20       RL     8430   Pave      Reg         HLS    AllPub
# 495  496          30  C (all)     7879   Pave      Reg         Lvl    AllPub
# 520  521         190       RL    10800   Pave      Reg         Lvl    AllPub
#
#     LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType  \
# 39     Inside       Gtl      Edwards       Norm       Norm   Duplex
# 48     Inside       Gtl      OldTown       Norm       Norm   2fmCon
# 78     Inside       Gtl       Sawyer       Norm       Norm   Duplex
# 88     Corner       Gtl       IDOTRR      Feedr      Feedr     1Fam
# 89     Inside       Gtl      CollgCr       Norm       Norm     1Fam
# 99     Inside       Gtl        NAmes       Norm       Norm     1Fam
# 108    Corner       Gtl       IDOTRR     Artery       Norm     1Fam
# 125    Inside       Gtl       IDOTRR       Norm       Norm   2fmCon
# 127    Inside       Gtl      OldTown      Feedr       Norm     1Fam
# 140       FR2       Gtl        NAmes       Norm       Norm     1Fam
# 148    Inside       Gtl      SawyerW       Norm       Norm     1Fam
# 155    Corner       Gtl      Edwards     Artery       Norm     1Fam
# 163    Inside       Gtl      OldTown       Norm       Norm     1Fam
# 165    Inside       Gtl      Edwards       Norm       Norm   2fmCon
# 198    Corner       Gtl      OldTown       Norm       Norm     1Fam
# 210    Inside       Gtl      Edwards       Norm       Norm     1Fam
# 241    Inside       Gtl      OldTown       Norm       Norm     1Fam
# 250    Inside       Gtl      BrkSide       Norm       Norm     1Fam
# 287    Corner       Gtl        NAmes       Norm       Norm     1Fam
# 291    Inside       Gtl        SWISU       Norm       Norm   2fmCon
# 307    Inside       Gtl       IDOTRR     Artery       Norm     1Fam
# 375    Inside       Sev      Edwards       Norm       Norm     1Fam
# 386       FR2       Gtl      Edwards      Feedr       Norm     1Fam
# 393    Corner       Gtl      BrkSide      Feedr       Norm     1Fam
# 431    Inside       Gtl      OldTown      Feedr       Norm     1Fam
# 434    Inside       Gtl      MeadowV       Norm       Norm    Twnhs
# 441    Inside       Gtl      Edwards       Norm       Norm   Duplex
# 464    Inside       Mod      CollgCr       Norm       Norm     1Fam
# 495    Inside       Gtl       IDOTRR       Norm       Norm     1Fam
# 520    Inside       Gtl      OldTown       Norm       Norm   2fmCon
#
#     HouseStyle  OverallQual  OverallCond  YearBuilt  YearRemodAdd RoofStyle  \
# 39      1Story            4            5       1955          1955     Gable
# 48      2Story            4            5       1920          2008     Gable
# 78      1Story            4            5       1968          1968       Hip
# 88      1.5Fin            3            2       1915          1982       Hip
# 89      1Story            4            5       1994          1995     Gable
# 99      1Story            4            5       1959          1959     Gable
# 108     1.5Fin            5            7       1919          2005     Gable
# 125     1.5Fin            6            8       1935          1982     Gable
# 127     1.5Unf            5            7       1930          1950     Gable
# 140     1Story            4            5       1971          1971     Gable
# 148     1Story            7            5       2004          2005     Gable
# 155     1.5Fin            6            5       1924          1950     Gable
# 163     1.5Unf            4            6       1956          1956     Gable
# 165     1.5Fin            5            7       1940          1999     Gable
# 198     2.5Fin            6            6       1912          1950     Gable
# 210     1Story            5            6       1925          1950     Gable
# 241     1Story            5            9       1945          1997     Gable
# 250     1Story            3            2       1940          1966     Gable
# 287     1Story            4            4       1971          1971     Gable
# 291     2Story            5            6       1912          2000     Gable
# 307     1.5Fin            6            7       1920          1950     Gable
# 375     1Story            1            1       1922          1950     Gable
# 386     1.5Fin            5            3       1910          1996   Gambrel
# 393     1Story            4            5       1941          1950     Gable
# 431     1.5Fin            6            7       1920          1998     Gable
# 434     SFoyer            4            7       1972          1972     Gable
# 441     1Story            4            4       1955          1955     Gable
# 464     1Story            5            5       1978          1978     Gable
# 495     1Story            4            5       1920          1950     Gable
# 520     2Story            4            7       1900          2000     Gable
#
#     RoofMatl Exterior1st Exterior2nd MasVnrType  MasVnrArea ExterQual  \
# 39   CompShg     AsbShng     Plywood       None       0.000        TA
# 48   CompShg     MetalSd     MetalSd       None       0.000        TA
# 78   CompShg     HdBoard     HdBoard       None       0.000        TA
# 88   CompShg     Plywood     Plywood       None       0.000        Fa
# 89   CompShg     VinylSd     VinylSd       None       0.000        TA
# 99   CompShg     Plywood     Plywood       None       0.000        TA
# 108  CompShg     CemntBd     CmentBd       None       0.000        TA
# 125  CompShg     Wd Sdng     Wd Sdng       None       0.000        TA
# 127  CompShg     WdShing     Wd Sdng       None       0.000        TA
# 140  CompShg     HdBoard     HdBoard       None       0.000        TA
# 148  CompShg     VinylSd     VinylSd    BrkFace     120.000        TA
# 155  CompShg     Wd Sdng     Wd Sdng       None       0.000        TA
# 163  CompShg     MetalSd     MetalSd       None       0.000        TA
# 165  CompShg     Wd Sdng     Wd Sdng       None       0.000        TA
# 198  CompShg     Wd Sdng     Wd Sdng       None       0.000        TA
# 210  CompShg      Stucco      Stucco       None       0.000        TA
# 241  CompShg     VinylSd     VinylSd       None       0.000        TA
# 250  CompShg     Wd Sdng     Plywood       None       0.000        TA
# 287  CompShg     HdBoard     HdBoard       None       0.000        TA
# 291  CompShg     VinylSd     VinylSd       None       0.000        TA
# 307  CompShg     MetalSd     MetalSd       None       0.000        TA
# 375  CompShg     Wd Sdng     Wd Sdng       None       0.000        Fa
# 386  CompShg     Wd Sdng     VinylSd       None       0.000        TA
# 393  CompShg     WdShing     Wd Shng       None       0.000        TA
# 431  CompShg     MetalSd     MetalSd       None       0.000        TA
# 434  CompShg     CemntBd     CmentBd       None       0.000        TA
# 441  CompShg     VinylSd     VinylSd    BrkFace     270.000        TA
# 464  CompShg     HdBoard     HdBoard    BrkFace     136.000        TA
# 495  CompShg     Wd Sdng     Wd Sdng       None       0.000        TA
# 520  CompShg     MetalSd     MetalSd       None       0.000        TA
#
#     ExterCond Foundation BsmtQual BsmtCond BsmtExposure BsmtFinType1  \
# 39         TA      PConc      NaN      NaN          NaN          NaN
# 48         TA     BrkTil       TA       TA           No          Unf
# 78         TA     CBlock       TA       TA           No          Unf
# 88         Fa     CBlock       TA       Fa           No          Unf
# 89         TA      PConc       Gd       TA           No          GLQ
# 99         TA     CBlock       TA       TA           No          ALQ
# 108        TA     CBlock       TA       TA           No          Unf
# 125        Fa     CBlock       TA       TA           Av          GLQ
# 127        Gd     BrkTil       TA       TA           No          LwQ
# 140        TA     CBlock       TA       TA           No          ALQ
# 148        TA      PConc       Gd       TA           No          GLQ
# 155        TA     BrkTil       TA       TA           No          Unf
# 163        TA     CBlock       TA       TA           No          Unf
# 165        Gd     BrkTil       TA       TA           No          ALQ
# 198        TA     CBlock       TA       TA           No          Unf
# 210        TA     CBlock       TA       TA           No          Rec
# 241        Gd     CBlock       TA       TA           No          ALQ
# 250        Po     CBlock       TA       TA           No          Unf
# 287        TA     CBlock       TA       TA           No          BLQ
# 291        Fa      PConc       TA       Fa           No          Rec
# 307        Fa     CBlock       TA       TA           No          Unf
# 375        Fa     BrkTil       Fa       Po           Gd          BLQ
# 386        Fa      PConc       TA       TA           No          Unf
# 393        TA     CBlock       TA       TA           No          Rec
# 431        TA     BrkTil       TA       TA           No          Unf
# 434        Gd     CBlock       Gd       TA           Av          ALQ
# 441        TA     CBlock       TA       TA           No          ALQ
# 464        TA     CBlock       Gd       TA           No          Rec
# 495        TA     CBlock       TA       TA           No          Rec
# 520        TA     BrkTil      NaN      NaN          NaN          NaN
#
#      BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF Heating  \
# 39            0          NaN           0          0            0    GasA
# 48            0          Unf           0        736          736    GasA
# 78            0          Unf           0       1768         1768    GasA
# 88            0          Unf           0       1013         1013    GasA
# 89          588          Unf           0        402          990    GasA
# 99          569          Unf           0        381          950    GasA
# 108           0          Unf           0        793          793    GasW
# 125         490          Unf           0         30          520    GasA
# 127         116          Unf           0        556          672    GasA
# 140         432          Unf           0        432          864    GasA
# 148         680          Unf           0        400         1080    GasA
# 155           0          Unf           0        572          572    Grav
# 163           0          Unf           0        882          882    GasA
# 165         351          Rec         181        112          644    GasA
# 198           0          Unf           0        755          755    GasA
# 210         468          Unf           0        396          864    GasA
# 241         329          Unf           0        357          686    GasA
# 250           0          Unf           0        728          728    GasA
# 287         614          Unf           0        244          858    GasA
# 291         210          Unf           0        570          780    GasA
# 307           0          Unf           0        319          319    GasA
# 375         350          Unf           0        333          683    GasA
# 386           0          Unf           0        658          658    GasA
# 393         266          Unf           0        522          788    GasA
# 431           0          Unf           0        901          901    GasA
# 434         495          Unf           0        135          630    GasA
# 441         133          Unf           0       1307         1440    GasA
# 464         616          Unf           0        424         1040    GasA
# 495         495          Unf           0        225          720    GasA
# 520           0          NaN           0          0            0    GasA
#
#     HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 39         TA          N      FuseP      1152         0             0
# 48         Gd          Y      SBrkr       736       716             0
# 78         TA          N      SBrkr      1768         0             0
# 88         TA          N      SBrkr      1013         0           513
# 89         Ex          Y      SBrkr       990         0             0
# 99         Fa          Y      SBrkr      1225         0             0
# 108        TA          N      FuseF       997       520             0
# 125        Gd          N      SBrkr       520         0           234
# 127        Ex          Y      SBrkr       840         0             0
# 140        TA          Y      SBrkr       864         0             0
# 148        Ex          Y      SBrkr      1080         0             0
# 155        Fa          N      FuseF       572       524             0
# 163        Ex          Y      SBrkr       882         0             0
# 165        Gd          Y      SBrkr       808       547             0
# 198        Ex          Y      SBrkr       929       929           371
# 210        TA          N      FuseA       864         0             0
# 241        Gd          Y      SBrkr       866         0             0
# 250        Ex          Y      SBrkr      1306         0             0
# 287        TA          Y      SBrkr       858         0             0
# 291        Ex          N      SBrkr       936       780             0
# 307        TA          Y      FuseA      1035       371             0
# 375        Gd          N      FuseA       904         0             0
# 386        TA          Y      SBrkr       658       526             0
# 393        TA          Y      FuseA       788         0             0
# 431        Gd          Y      SBrkr      1088       110             0
# 434        Gd          Y      SBrkr       630         0             0
# 441        TA          N      FuseF      1440         0             0
# 464        TA          Y      SBrkr      1040         0             0
# 495        TA          N      FuseA       720         0             0
# 520        TA          N      FuseA       694       600             0
#
#      GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 39        1152             0             0         2         0             2
# 48        1452             0             0         2         0             2
# 78        1768             0             0         2         0             4
# 88        1526             0             0         1         0             2
# 89         990             1             0         1         0             3
# 99        1225             1             0         1         1             3
# 108       1517             0             0         2         0             3
# 125        754             1             0         1         0             2
# 127        840             0             0         1         0             3
# 140        864             0             0         1         0             3
# 148       1080             1             0         1         0             3
# 155       1096             0             0         1         0             2
# 163        882             0             0         1         0             1
# 165       1355             1             0         2         0             4
# 198       2229             0             0         1         0             5
# 210        864             1             0         1         0             2
# 241        866             0             0         1         0             2
# 250       1306             0             0         1         0             3
# 287        858             0             0         1         0             3
# 291       1716             1             0         2         0             6
# 307       1406             0             0         1         0             3
# 375        904             1             0         0         1             1
# 386       1184             0             0         1         0             5
# 393        788             0             0         1         0             2
# 431       1198             0             0         1         0             4
# 434        630             1             0         1         0             1
# 441       1440             0             0         2         0             4
# 464       1040             0             0         2         0             3
# 495        720             0             0         1         0             2
# 520       1294             0             0         2         0             3
#
#      KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces GarageType  \
# 39              2          Fa             6        Typ           0        NaN
# 48              3          TA             8        Typ           0        NaN
# 78              2          TA             8        Typ           0        NaN
# 88              1          Fa             6        Typ           0        NaN
# 89              1          TA             5        Typ           0        NaN
# 99              1          TA             6        Typ           0        NaN
# 108             1          Fa             7        Typ           0        NaN
# 125             1          TA             5        Typ           0        NaN
# 127             1          TA             5        Typ           1        NaN
# 140             1          TA             5        Typ           1        NaN
# 148             1          Gd             6        Typ           0        NaN
# 155             1          TA             5        Typ           0        NaN
# 163             1          TA             4        Typ           0        NaN
# 165             2          TA             6        Typ           0        NaN
# 198             1          TA             8        Typ           0        NaN
# 210             1          TA             5        Typ           0        NaN
# 241             1          Gd             4        Typ           0        NaN
# 250             1          Fa             6        Mod           0        NaN
# 287             1          TA             5        Typ           0        NaN
# 291             1          Fa             9        Typ           0        NaN
# 307             1          Fa             6        Typ           0        NaN
# 375             1          Fa             4       Maj1           0        NaN
# 386             1          TA             8        Typ           0        NaN
# 393             1          TA             4        Typ           2        NaN
# 431             1          TA             7        Typ           0        NaN
# 434             1          TA             3        Typ           0        NaN
# 441             2          Fa             8        Typ           0        NaN
# 464             1          TA             5        Typ           0        NaN
# 495             1          TA             4        Typ           0        NaN
# 520             2          TA             7        Typ           0        NaN
#
#      GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual GarageCond  \
# 39           nan          NaN           0           0        NaN        NaN
# 48           nan          NaN           0           0        NaN        NaN
# 78           nan          NaN           0           0        NaN        NaN
# 88           nan          NaN           0           0        NaN        NaN
# 89           nan          NaN           0           0        NaN        NaN
# 99           nan          NaN           0           0        NaN        NaN
# 108          nan          NaN           0           0        NaN        NaN
# 125          nan          NaN           0           0        NaN        NaN
# 127          nan          NaN           0           0        NaN        NaN
# 140          nan          NaN           0           0        NaN        NaN
# 148          nan          NaN           0           0        NaN        NaN
# 155          nan          NaN           0           0        NaN        NaN
# 163          nan          NaN           0           0        NaN        NaN
# 165          nan          NaN           0           0        NaN        NaN
# 198          nan          NaN           0           0        NaN        NaN
# 210          nan          NaN           0           0        NaN        NaN
# 241          nan          NaN           0           0        NaN        NaN
# 250          nan          NaN           0           0        NaN        NaN
# 287          nan          NaN           0           0        NaN        NaN
# 291          nan          NaN           0           0        NaN        NaN
# 307          nan          NaN           0           0        NaN        NaN
# 375          nan          NaN           0           0        NaN        NaN
# 386          nan          NaN           0           0        NaN        NaN
# 393          nan          NaN           0           0        NaN        NaN
# 431          nan          NaN           0           0        NaN        NaN
# 434          nan          NaN           0           0        NaN        NaN
# 441          nan          NaN           0           0        NaN        NaN
# 464          nan          NaN           0           0        NaN        NaN
# 495          nan          NaN           0           0        NaN        NaN
# 520          nan          NaN           0           0        NaN        NaN
#
#     PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 39           N           0            0              0          0
# 48           N           0            0            102          0
# 78           Y           0            0              0          0
# 88           N           0            0            156          0
# 89           Y           0            0              0          0
# 99           Y         352            0              0          0
# 108          N           0            0            144          0
# 125          N          53            0              0          0
# 127          N           0            0              0          0
# 140          Y           0            0              0          0
# 148          Y           0            0              0          0
# 155          N           0            8            128          0
# 163          Y           0            0              0          0
# 165          Y         140            0              0          0
# 198          Y           0          198             30          0
# 210          Y           0            0             96          0
# 241          Y          58           42              0          0
# 250          Y         263            0              0          0
# 287          Y           0            0              0          0
# 291          N           0          184              0          0
# 307          N           0          144              0          0
# 375          Y           0            0              0          0
# 386          N           0          151              0          0
# 393          Y           0            0              0          0
# 431          N           0           98              0          0
# 434          Y          88            0              0          0
# 441          Y           0            0              0          0
# 464          Y           0            0              0          0
# 495          N           0          523            115          0
# 520          N         220          114            210          0
#
#      ScreenPorch  PoolArea  MiscVal  MoSold  YrSold SaleType SaleCondition  \
# 39             0         0        0       6    2008       WD       AdjLand
# 48             0         0        0       6    2009      New       Partial
# 78             0         0        0       4    2010       WD        Normal
# 88             0         0        0      10    2009    ConLD       Abnorml
# 89             0         0        0       8    2007       WD        Normal
# 99             0         0      400       1    2010       WD        Normal
# 108            0         0        0       8    2007       WD        Normal
# 125            0         0        0       6    2006       WD        Normal
# 127            0         0        0       6    2007       WD        Normal
# 140            0         0        0       4    2010    ConLI        Normal
# 148            0         0        0       4    2008       WD        Normal
# 155            0         0        0       4    2008       WD        Normal
# 163            0         0        0       4    2007       WD        Normal
# 165            0         0        0       9    2008       WD        Normal
# 198            0         0        0       7    2009       WD       Abnorml
# 210            0         0        0       4    2008       WD        Normal
# 241            0         0        0       8    2007       WD        Normal
# 250            0         0      450       5    2010       WD        Normal
# 287            0         0        0       6    2006       WD        Normal
# 291            0         0        0       3    2008       WD        Normal
# 307            0         0        0       3    2008       WD        Normal
# 375            0         0        0       3    2009       WD        Normal
# 386            0         0        0       5    2006       WD       AdjLand
# 393            0         0        0       4    2006       WD       Abnorml
# 431            0         0        0       9    2008    ConLD       Abnorml
# 434            0         0        0       6    2008       WD        Normal
# 441            0         0        0       9    2008       WD        Normal
# 464            0         0        0       8    2009       WD        Normal
# 495            0         0        0      11    2009       WD       Abnorml
# 520            0         0        0       8    2008       WD        Normal
#
#      SalePrice
# 39       82000
# 48      113000
# 78      136500
# 88       85000
# 89      123600
# 99      128950
# 108     115000
# 125      84500
# 127      87000
# 140     115000
# 148     141000
# 155      79000
# 163     103200
# 165     127500
# 198     104000
# 210      98000
# 241     110500
# 250      76500
# 287      88000
# 291     135900
# 307      89500
# 375      61000
# 386      81000
# 393     100000
# 431      79900
# 434      81000
# 441     118000
# 464     124000
# 495      34900
# 520     106250

# %% [markdown]
# All raws with NaNs have 0 Cars. It makes me think that there's no garage in the house. In this case according to description of the dataset it should contain NA. The same with Basement. If square feet = 0, there's no basement in the house and basement quality must contain NA.

# %%
# 'GarageQual', 'GarageCond', 'GarageFinish', 'GarageType', 'GarageYrBlt', 
# BsmtCond', 'BsmtQual' , 'BsmtExposure, 'BsmtFinType1'
train['GarageQual'].fillna('NA', inplace=True)
train['GarageCond'].fillna('NA', inplace=True)
train['GarageFinish'].fillna('NA', inplace=True)
train['GarageType'].fillna('NA', inplace=True)
train['GarageYrBlt'].fillna('NA', inplace=True)
train['BsmtCond'].fillna('NA', inplace=True)
train['BsmtQual'].fillna('NA', inplace=True)
train['BsmtExposure'].fillna('NA', inplace=True)
train['BsmtFinType1'].fillna('NA', inplace=True)

# %%
test['GarageQual'].fillna('NA', inplace=True)
test['GarageCond'].fillna('NA', inplace=True)
test['GarageFinish'].fillna('NA', inplace=True)
test['GarageType'].fillna('NA', inplace=True)
test['GarageYrBlt'].fillna('NA', inplace=True)
test['BsmtCond'].fillna('NA', inplace=True)
test['BsmtQual'].fillna('NA', inplace=True)
test['BsmtExposure'].fillna('NA', inplace=True)
test['BsmtFinType1'].fillna('NA', inplace=True)

# %%
msngo.matrix(train, labels=True, fontsize=12);

# %%
msngo.matrix(test, labels=True, fontsize=12);

# %% [markdown]
# It's strange that some columns describing quality contain values and some of them contain text. So, if we would like to check whether this features are correlated or not, it would be nice to have them evaluated. Let's have a closer look.

# %%
CatLs = train.describe(include='all').T['unique'].dropna().sort_values()
CatLs
# Out:
# Street            2
# Utilities         2
# CentralAir        2
# LandSlope         3
# PavedDrive        3
# GarageFinish      4
# LotShape          4
# LandContour       4
# ExterQual         4
# MasVnrType        4
# KitchenQual       4
# BsmtCond          5
# BsmtQual          5
# ExterCond         5
# HeatingQC         5
# MSZoning          5
# BsmtExposure      5
# BldgType          5
# LotConfig         5
# Electrical        5
# GarageQual        6
# Heating           6
# GarageCond        6
# BsmtFinType2      6
# Foundation        6
# RoofStyle         6
# SaleCondition     6
# Functional        7
# GarageType        7
# BsmtFinType1      7
# RoofMatl          8
# HouseStyle        8
# Condition2        8
# SaleType          9
# Condition1        9
# Exterior1st      15
# Exterior2nd      16
# Neighborhood     25
# GarageYrBlt      98
# Name: unique, dtype: object

# %% [markdown]
# Such much?! I don't have time for all of you. The fattiest will be thrown out first. Some will be considered.

# %%
Cat2Num = [
    'Street', 'Utilities', 'CentralAir', 'PavedDrive', 'LandSlope',
    'KitchenQual', 'BsmtCond', 'BsmtQual', 'ExterQual', 'Electrical',
    'HeatingQC', 'ExterCond', 'Heating', 'BsmtFinType1', 'BsmtFinType2',
    'SaleCondition'
]

# %%
for Cat in Cat2Num:
    print (sns.catplot(x=Cat, y="SalePrice", data=train));
# Out:
# <seaborn.axisgrid.FacetGrid object at 0x1a259db6a0>
# <seaborn.axisgrid.FacetGrid object at 0x1a20db7eb8>
# <seaborn.axisgrid.FacetGrid object at 0x1a20d73e48>
# <seaborn.axisgrid.FacetGrid object at 0x1a282b1ac8>
# <seaborn.axisgrid.FacetGrid object at 0x1a28296940>
# <seaborn.axisgrid.FacetGrid object at 0x1a20192128>
# <seaborn.axisgrid.FacetGrid object at 0x1a27e63eb8>
# <seaborn.axisgrid.FacetGrid object at 0x1a1fac34a8>
# <seaborn.axisgrid.FacetGrid object at 0x1a1fba7358>
# <seaborn.axisgrid.FacetGrid object at 0x1a1fac34a8>
# <seaborn.axisgrid.FacetGrid object at 0x1a1f8ebf98>
# <seaborn.axisgrid.FacetGrid object at 0x1a1fac34a8>
# <seaborn.axisgrid.FacetGrid object at 0x1a1f8c6438>
# <seaborn.axisgrid.FacetGrid object at 0x1a1f8ebf98>
# <seaborn.axisgrid.FacetGrid object at 0x1a1fa67cc0>
# <seaborn.axisgrid.FacetGrid object at 0x1a240a7c18>

# %%
# Add new column Central Cond with values 0 and 1 for N and Y
train["CentralAirV"] = np.where (train.CentralAir == 'N', 0, 1)
test["CentralAirV"] = np.where (test.CentralAir == 'N', 0, 1)

# %% [markdown]
# Overall quality of the house in this dataset was estimated from 1 to 10. But some features contain categorical representation of the estimates. Let's fix it.

# %%
Vals = {'NA': 0, 'Po': 2, 'Fa': 4, 'TA': 6, 'Gd': 8, 'Ex': 10}

# %%
train['KitchenQualV'] = train['KitchenQual'].map (Vals)
train['BsmtQualV'] = train['BsmtQual'].map (Vals)
train['BsmtCondV'] = train['BsmtCond'].map (Vals)
train['ExterQualV'] = train['ExterQual'].map (Vals)
train['HeatingQCV'] = train['HeatingQC'].map (Vals)
train['ExterCondV'] = train['ExterCond'].map (Vals)

# %%
test['KitchenQualV'] = test['KitchenQual'].map (Vals)
test['BsmtQualV'] = test['BsmtQual'].map (Vals)
test['BsmtCondV'] = test['BsmtCond'].map (Vals)
test['ExterQualV'] = test['ExterQual'].map (Vals)
test['HeatingQCV'] = test['HeatingQC'].map (Vals)
test['ExterCondV'] = test['ExterCond'].map (Vals)

# %%
SaleCond = {'Normal': 1, 'Abnorml': 0, 'Partial': 1, 'AdjLand': 0, 'Alloca': 0, 'Family': 0}

# %%
train['SaleConditionV'] = train['SaleCondition'].map(SaleCond)

# %%
test['SaleConditionV'] = train['SaleCondition'].map(SaleCond)

# %%
train.head()
# Out:
#    Id  MSSubClass MSZoning  LotArea Street LotShape LandContour Utilities  \
# 0   1          60       RL     8450   Pave      Reg         Lvl    AllPub
# 1   2          20       RL     9600   Pave      Reg         Lvl    AllPub
# 2   3          60       RL    11250   Pave      IR1         Lvl    AllPub
# 3   4          70       RL     9550   Pave      IR1         Lvl    AllPub
# 4   5          60       RL    14260   Pave      IR1         Lvl    AllPub
#
#   LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType HouseStyle  \
# 0    Inside       Gtl      CollgCr       Norm       Norm     1Fam     2Story
# 1       FR2       Gtl      Veenker      Feedr       Norm     1Fam     1Story
# 2    Inside       Gtl      CollgCr       Norm       Norm     1Fam     2Story
# 3    Corner       Gtl      Crawfor       Norm       Norm     1Fam     2Story
# 4       FR2       Gtl      NoRidge       Norm       Norm     1Fam     2Story
#
#    OverallQual  OverallCond  YearBuilt  YearRemodAdd RoofStyle RoofMatl  \
# 0            7            5       2003          2003     Gable  CompShg
# 1            6            8       1976          1976     Gable  CompShg
# 2            7            5       2001          2002     Gable  CompShg
# 3            7            5       1915          1970     Gable  CompShg
# 4            8            5       2000          2000     Gable  CompShg
#
#   Exterior1st Exterior2nd MasVnrType  MasVnrArea ExterQual ExterCond  \
# 0     VinylSd     VinylSd    BrkFace     196.000        Gd        TA
# 1     MetalSd     MetalSd       None       0.000        TA        TA
# 2     VinylSd     VinylSd    BrkFace     162.000        Gd        TA
# 3     Wd Sdng     Wd Shng       None       0.000        TA        TA
# 4     VinylSd     VinylSd    BrkFace     350.000        Gd        TA
#
#   Foundation BsmtQual BsmtCond BsmtExposure BsmtFinType1  BsmtFinSF1  \
# 0      PConc       Gd       TA           No          GLQ         706
# 1     CBlock       Gd       TA           Gd          ALQ         978
# 2      PConc       Gd       TA           Mn          GLQ         486
# 3     BrkTil       TA       Gd           No          ALQ         216
# 4      PConc       Gd       TA           Av          GLQ         655
#
#   BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF Heating HeatingQC  \
# 0          Unf           0        150          856    GasA        Ex
# 1          Unf           0        284         1262    GasA        Ex
# 2          Unf           0        434          920    GasA        Ex
# 3          Unf           0        540          756    GasA        Gd
# 4          Unf           0        490         1145    GasA        Ex
#
#   CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  \
# 0          Y      SBrkr       856       854             0       1710
# 1          Y      SBrkr      1262         0             0       1262
# 2          Y      SBrkr       920       866             0       1786
# 3          Y      SBrkr       961       756             0       1717
# 4          Y      SBrkr      1145      1053             0       2198
#
#    BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr  \
# 0             1             0         2         1             3             1
# 1             0             1         2         0             3             1
# 2             1             0         2         1             3             1
# 3             1             0         1         0             3             1
# 4             1             0         2         1             4             1
#
#   KitchenQual  TotRmsAbvGrd Functional  Fireplaces GarageType GarageYrBlt  \
# 0          Gd             8        Typ           0     Attchd    2003.000
# 1          TA             6        Typ           1     Attchd    1976.000
# 2          Gd             6        Typ           1     Attchd    2001.000
# 3          Gd             7        Typ           1     Detchd    1998.000
# 4          Gd             9        Typ           1     Attchd    2000.000
#
#   GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# 0          RFn           2         548         TA         TA          Y
# 1          RFn           2         460         TA         TA          Y
# 2          RFn           2         608         TA         TA          Y
# 3          Unf           3         642         TA         TA          Y
# 4          RFn           3         836         TA         TA          Y
#
#    WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  \
# 0           0           61              0          0            0         0
# 1         298            0              0          0            0         0
# 2           0           42              0          0            0         0
# 3           0           35            272          0            0         0
# 4         192           84              0          0            0         0
#
#    MiscVal  MoSold  YrSold SaleType SaleCondition  SalePrice  CentralAirV  \
# 0        0       2    2008       WD        Normal     208500            1
# 1        0       5    2007       WD        Normal     181500            1
# 2        0       9    2008       WD        Normal     223500            1
# 3        0       2    2006       WD       Abnorml     140000            1
# 4        0      12    2008       WD        Normal     250000            1
#
#    KitchenQualV  BsmtQualV  BsmtCondV  ExterQualV  HeatingQCV  ExterCondV  \
# 0             8          8          6           8          10           6
# 1             6          8          6           6          10           6
# 2             8          8          6           8          10           6
# 3             8          6          8           6           8           6
# 4             8          8          6           8          10           6
#
#    SaleConditionV
# 0               1
# 1               1
# 2               1
# 3               0
# 4               1

# %%
fig, ax = plt.subplots (figsize=(12,8))
sns.distplot(train.SalePrice, fit=stats.norm, bins=30);

#get fit params
mu, sigma = stats.norm.fit(train.SalePrice)

#legend and label
plt.legend(["normal dist. ($\mu=${0:.2g}, $\sigma=${1:.2f})".format(mu, sigma)])
plt.ylabel('Frequency');

# %%
fig, ax = plt.subplots (figsize=(12,8))
res = stats.probplot(train['SalePrice'], plot=plt)

# %%
corrmat = train.corr()
fig, ax = plt.subplots (figsize=(12,10))
sns.heatmap (corrmat, cmap='Blues');

# %%
corrmat['SalePrice'].sort_values(ascending=False)
# Out:
# SalePrice         1.000
# OverallQual       0.791
# GrLivArea         0.709
# ExterQualV        0.683
# KitchenQualV      0.660
# GarageCars        0.640
# GarageArea        0.623
# TotalBsmtSF       0.614
# 1stFlrSF          0.606
# BsmtQualV         0.585
# FullBath          0.561
# TotRmsAbvGrd      0.534
# YearBuilt         0.523
# YearRemodAdd      0.507
# MasVnrArea        0.477
# Fireplaces        0.467
# HeatingQCV        0.428
# BsmtFinSF1        0.386
# WoodDeckSF        0.324
# 2ndFlrSF          0.319
# OpenPorchSF       0.316
# HalfBath          0.284
# LotArea           0.264
# CentralAirV       0.251
# BsmtFullBath      0.227
# BsmtUnfSF         0.214
# BsmtCondV         0.213
# BedroomAbvGr      0.168
# SaleConditionV    0.135
# ScreenPorch       0.111
# PoolArea          0.092
# MoSold            0.046
# 3SsnPorch         0.045
# ExterCondV        0.019
# BsmtFinSF2       -0.011
# BsmtHalfBath     -0.017
# MiscVal          -0.021
# Id               -0.022
# LowQualFinSF     -0.026
# YrSold           -0.029
# OverallCond      -0.078
# MSSubClass       -0.084
# EnclosedPorch    -0.129
# KitchenAbvGr     -0.136
# Name: SalePrice, dtype: float64

# %%
# main factors influencing SalePrice:
Sfctr = [
    'SalePrice', 'OverallQual', 'GrLivArea', 'ExterQualV', 'KitchenQualV',
    'BsmtQualV', 'GarageCars', 'TotalBsmtSF', 'FullBath',
    'TotRmsAbvGrd', 'YearBuilt', 'YearRemodAdd'
]

# %%
# let's look at them through the OKULAR O_O
fig, ax = plt.subplots (figsize=(10, 6))
cm = np.corrcoef(train[Sfctr].values.T)
sns.set(font_scale=1)
sns.heatmap (cm, cmap='Blues', annot=True, fmt='.2f', yticklabels=Sfctr, xticklabels=Sfctr);

# %%
# Oh, wait a second... is it safe? is it clear?
null = train[train[Sfctr] == 0][Sfctr].count()
NaN = train[train[Sfctr].isnull()][Sfctr].count()
NoData = pd.concat ([null, NaN], axis=1, keys=['null', 'NaN'])
NoData
# Out:
#               null  NaN
# SalePrice        0    0
# OverallQual      0    0
# GrLivArea        0    0
# ExterQualV       0    0
# KitchenQualV     0    0
# BsmtQualV       37    0
# GarageCars      81    0
# TotalBsmtSF     37    0
# FullBath         9    0
# TotRmsAbvGrd     0    0
# YearBuilt        0    0
# YearRemodAdd     0    0

# %% [markdown]
# main factors that influence Sale Price don't have missing values. Garage cars and Total basement with zero values seem OK, since it is possible that there's no garage or basement in the house in fact

# %% [markdown]
# ### How many of us are lazy?

# %%
len(train[train['YearBuilt'] != train['YearRemodAdd']])/len(train)
# Out:
# 0.4767123287671233

# %% [markdown]
# almost 50% never remodel their houses (or... we don't know about that since they are smart enough to keep it in secret). not bad!
# But does it affect Sale Price?

# %%
x = train['YearRemodAdd'] - train['YearBuilt']
sns.jointplot(x=x, y="SalePrice", kind="reg", height=10, data=train)
plt.xlabel ('# of years since last Remodel')
plt.show()

# %% [markdown]
# I really don't know. There's a light negative tendency, but it doesn't look like we should take it into account.

# %% [markdown]
# ### Wide look at the data

# %%
print(Sfctr)
g = sns.PairGrid(train[Sfctr])
g.map_upper(sns.scatterplot)
g.map_lower(sns.kdeplot)
g.map_diag(plt.hist);
# Out:
# ['SalePrice', 'OverallQual', 'GrLivArea', 'ExterQualV', 'KitchenQualV', 'BsmtQualV', 'GarageCars', 'TotalBsmtSF', 'FullBath', 'TotRmsAbvGrd', 'YearBuilt', 'YearRemodAdd']

# %% [markdown]
# ### What about outliers?

# %%
sns.jointplot(x="GrLivArea", y="SalePrice", kind="reg", height=10, data=train);

# %%
# remove outliers (huge living area for a suspiciously low price)
Ctrain = train.drop(train[(train['GrLivArea'] > 4000) & (train['SalePrice'] < 200000)].index) # Cleaned train data

# %%
sns.jointplot(x="TotalBsmtSF", y="SalePrice", kind="reg", height=10, data=train);

# %%
# remove outliers (huge basement for a suspiciously low price)
Ctrain = Ctrain.drop(Ctrain[(Ctrain['TotalBsmtSF'] > 6000) & (Ctrain['SalePrice'] < 200000)].index)

# %%
sns.jointplot(x="TotRmsAbvGrd", y="SalePrice", kind="reg", height=10, data=train);

# %%
train[train['TotRmsAbvGrd'] == 14]

# %% [markdown]
# huge house with 14 rooms at a low price... hm. But Sale condition is abnormal. OK, we will leave it as it is. Lets have a look a Sale conditions once more. It's strange that correlation with SalePrice is low.

# %%
fig, ax = plt.subplots (figsize=(10, 8))
sns.scatterplot(x="TotalBsmtSF", y="SalePrice", hue="SaleConditionV", data=Ctrain);

# %% [markdown]
# well, OK.

# %% [markdown]
# ## FINALLY REGRESSION

# %%
target = Ctrain.SalePrice

# %%
features = [
    'OverallQual', 'GrLivArea', 'ExterQualV', 'KitchenQualV', 'BsmtQualV',
    'GarageCars', 'TotalBsmtSF', 'FullBath', 'TotRmsAbvGrd', 'YearBuilt',
    'YearRemodAdd'
]

# %%
# make sure our test data contains all necessary information
test [features].describe()

# %% [markdown]
# ### Some more minor cleaning (

# %%
test[test['KitchenQual'].isna()]

# %%
# Kitchen is above grade so I'll give it 8 
test['KitchenQualV'].fillna(8, inplace=True)

# %%
test[test['GarageCars'].isna()]

# %%
# There's no garage in the house so I'll give 0
test['GarageCars'].fillna(0, inplace=True)

# %%
test[test['TotalBsmtSF'].isna()]

# %%
# and there's no basement in the house also
test['TotalBsmtSF'].fillna(0, inplace=True)

# %%
# sets for modelling
Ctrain = Ctrain [features]
Ctest = test [features]

# %%
STDtrain = StandardScaler().fit_transform(Ctrain)
STDtest = StandardScaler().fit_transform(Ctest)

# %%
X_train, X_test, y_train, y_test = train_test_split (Ctrain, target, test_size = 0.3, random_state = 0)

# %% [markdown]
# ### Linear regression

# %%
LinReg = LinearRegression().fit(Ctrain, target)

# %%
LinReg_y_predict = LinReg.predict (Ctest)

# %%
LR = pd.DataFrame({'LR': LinReg_y_predict})

# %% [markdown]
# ### Ridge

# %%
Ridge = RidgeCV(alphas= [0.01, 0.03, 0.06, 0.1, 0.3, 0.6, 1, 3, 6, 10, 30, 60]).fit (Ctrain, target)

# %%
Ridge_y_predict = Ridge.predict (Ctest)

# %%
R = pd.DataFrame({'R': Ridge_y_predict})

# %% [markdown]
# ### Lasso

# %%
Lasso = LassoCV(
    alphas=[
        0.0001, 0.0003, 0.0006, 0.001, 0.003, 0.006, 0.01, 0.03, 0.06, 0.1,
        0.3, 0.6, 1
    ],
    max_iter=50000,
    cv=10).fit(Ctrain, target)

# %%
Lasso_y_predict = Lasso.predict (Ctest)

# %%
LS = pd.DataFrame({'LS': Lasso_y_predict})

# %% [markdown]
# ### Compare results

# %%
Sample = pd.read_csv ('../data/sample_submission.csv')

# %%
FinTest = pd.concat ([test, Sample, LR, R, LS], axis=1)

# %%
FinTest.head()

# %%
sns.jointplot(x="SalePrice", y="LR", data=FinTest);

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)

y_train_pred = lr.predict(X_train)
y_test_pred = lr.predict(X_test)

plt.scatter(y_train_pred, y_train, c = "blue", marker = "s", label = "Training data")
plt.scatter(y_test_pred, y_test, c = "lightgreen", marker = "s", label = "Validation data")
plt.title("Linear regression")
plt.xlabel("Predicted values")
plt.ylabel("Real values")
plt.legend(loc = "upper left")
plt.plot([10.5, 13.5], [10.5, 13.5], c = "red")
plt.show()

plt.scatter(y_train_pred, y_train_pred - y_train, c = "blue", marker = "s", label = "Training data")
plt.scatter(y_test_pred, y_test_pred - y_test, c = "lightgreen", marker = "s", label = "Validation data")
plt.title("Linear regression")
plt.xlabel("Predicted values")
plt.ylabel("Residuals")
plt.legend(loc = "upper left")
plt.hlines(y = 0, xmin = 10.5, xmax = 13.5, color = "red")
plt.show()

# %%
fig, ax = plt.subplots (figsize=(12,10))
plt.scatter (x=FinTest.GrLivArea, y=FinTest.SalePrice, c = "red", marker = "p", label = "Sample")
plt.scatter (x=FinTest.GrLivArea, y=FinTest.LR, c = "blue", marker = "s", label = "Linear")
plt.scatter (x=FinTest.GrLivArea, y=FinTest.R, c = "green", marker = "v", label = "Ridge")
plt.scatter (x=FinTest.GrLivArea, y=FinTest.LS, c = "green", marker = "v", label = "Lasso");

# %%
FinTest[FinTest['LR'] < 0]

# %% [markdown]
# ### Intermediate conclusion

# %% [markdown]
# It doesn't seem like a good model ((( I will continue next time. The Ultimate Forecasting Model is on the GO
